# %% [markdown]
# <a href="https://colab.research.google.com/github/melvionmatanos2008/mfmpython1/blob/main/mfm_python_project_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Analyzing New York City COVID-19 Daily Counts of Cases, Hospitalizations, and Deaths
# # Importing required libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import numpy as np

# %%
df = pd.read_csv ('https://data.cityofnewyork.us/resource/cwmx-mvra.csv')

# %%
pd.set_option('display.max_rows', df.shape[0]+1)

# %%
df
# Out:
#                 extract_date  ... number_deaths
# 0    2021-06-20T00:00:00.000  ...            39
# 1    2021-06-20T00:00:00.000  ...             5
# 2    2021-06-20T00:00:00.000  ...            16
# 3    2021-06-20T00:00:00.000  ...            35
# 4    2021-06-20T00:00:00.000  ...             0
# 5    2021-06-20T00:00:00.000  ...            47
# 6    2021-06-20T00:00:00.000  ...            26
# 7    2021-06-20T00:00:00.000  ...             0
# 8    2021-06-20T00:00:00.000  ...            23
# 9    2021-06-20T00:00:00.000  ...            73
# 10   2021-06-20T00:00:00.000  ...             0
# 11   2021-06-20T00:00:00.000  ...            26
# 12   2021-06-20T00:00:00.000  ...           298
# 13   2021-06-20T00:00:00.000  ...            32
# 14   2021-06-20T00:00:00.000  ...             8
# 15   2021-06-20T00:00:00.000  ...             0
# 16   2021-06-20T00:00:00.000  ...             0
# 17   2021-06-20T00:00:00.000  ...            57
# 18   2021-06-20T00:00:00.000  ...             0
# ...

# %%
df.head(10)
# Out:
#               extract_date  ... number_deaths
# 0  2021-06-20T00:00:00.000  ...            39
# 1  2021-06-20T00:00:00.000  ...             5
# 2  2021-06-20T00:00:00.000  ...            16
# 3  2021-06-20T00:00:00.000  ...            35
# 4  2021-06-20T00:00:00.000  ...             0
# 5  2021-06-20T00:00:00.000  ...            47
# 6  2021-06-20T00:00:00.000  ...            26
# 7  2021-06-20T00:00:00.000  ...             0
# 8  2021-06-20T00:00:00.000  ...            23
# 9  2021-06-20T00:00:00.000  ...            73
#
# [10 rows x 6 columns]

# %%
df.tail()
# Out:
#                 extract_date  ... number_deaths
# 995  2021-06-19T00:00:00.000  ...            27
# 996  2021-06-19T00:00:00.000  ...            46
# 997  2021-06-19T00:00:00.000  ...           322
# 998  2021-06-19T00:00:00.000  ...             0
# 999  2021-06-19T00:00:00.000  ...            65
#
# [5 rows x 6 columns]

# %%
df.describe()
# Out:
#        number_tested  number_confirmed  number_hospitalized  number_deaths
# count    1000.000000       1000.000000          1000.000000    1000.000000
# mean    11321.663000       1508.401000           212.521000      65.613000
# std      6399.660436       1270.990698           331.767333     144.220126
# min         1.000000          0.000000             0.000000       0.000000
# 25%      6926.250000        625.000000            71.000000      12.000000
# 50%     11368.500000       1385.000000           137.000000      26.000000
# 75%     16452.000000       1983.000000           201.000000      44.000000
# max     24521.000000       6792.000000          1972.000000     906.000000

# %% [markdown]
# # Data wrangling and cleaning.
# #Finding the missing values.

# %%
df.isnull().sum()
# Out:
# extract_date           0
# specimen_date          0
# number_tested          0
# number_confirmed       0
# number_hospitalized    0
# number_deaths          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   extract_date         1000 non-null   object
#  1   specimen_date        1000 non-null   object
#  2   number_tested        1000 non-null   int64
#  3   number_confirmed     1000 non-null   int64
#  4   number_hospitalized  1000 non-null   int64
#  5   number_deaths        1000 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 47.0+ KB

# %% [markdown]
# # Data types summary for each columns.

# %%
df.dtypes
# Out:
# extract_date           object
# specimen_date          object
# number_tested           int64
# number_confirmed        int64
# number_hospitalized     int64
# number_deaths           int64
# dtype: object

# %% [markdown]
# # Showing example of a specific data types.

# %%
df.select_dtypes(include=['number'])
# Out:
#      number_tested  number_confirmed  number_hospitalized  number_deaths
# 0            20416              2701                  214             39
# 1            10733               336                   37              5
# 2            15617              1176                  124             16
# 3            16535              1483                  147             35
# 4                1                 0                    0              0
# 5            15641              1293                  152             47
# 6            13508              1465                  138             26
# 7             9867               119                   17              0
# 8            13953              1572                  159             23
# 9            23136              3867                  268             73
# 10              14                 4                    1              0
# 11           15986              1866                  138             26
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.max()
# Out:
# extract_date           2021-06-20T00:00:00.000
# specimen_date          2021-06-19T00:00:00.000
# number_tested                            24521
# number_confirmed                          6792
# number_hospitalized                       1972
# number_deaths                              906
# dtype: object

# %%
df.min()
# Out:
# extract_date           2021-06-19T00:00:00.000
# specimen_date          2020-01-02T00:00:00.000
# number_tested                                1
# number_confirmed                             0
# number_hospitalized                          0
# number_deaths                                0
# dtype: object

# %%
df.mean()
# Out:
# number_tested          11321.663
# number_confirmed        1508.401
# number_hospitalized      212.521
# number_deaths             65.613
# dtype: float64

# %%
df.groupby(["extract_date"]) ['number_deaths'].count()
# Out:
# extract_date
# 2021-06-19T00:00:00.000    476
# 2021-06-20T00:00:00.000    524
# Name: number_deaths, dtype: int64

# %%
df.groupby(["number_deaths"]) ['number_hospitalized'].count()
# Out:
# number_deaths
# 0      129
# 1       32
# 2        9
# 3       12
# 4        7
# 5        5
# 6        4
# 7        4
# 8        8
# 9       12
# 10      10
# 11       8
# 12      12
# 13      19
# 14      14
# 15      18
# 16      19
# 17       8
# 18      15
# 19      16
# 20      13
# 21      10
# 22      36
# 23      24
# 24      14
# 25      25
# 26      24
# 27      17
# 28      27
# 29      16
# 30      17
# 31      18
# 32      14
# 33      18
# 34      13
# 35      16
# 36       8
# 37      16
# 38      12
# 39      16
# 40       4
# 41       6
# 42       8
# 43       8
# 44      10
# 45       8
# 46      15
# 47       4
# 48       4
# 49       6
# 50      10
# 51       6
# 52       5
# 53       9
# 54       4
# 55       8
# 56       2
# 57       6
# 59       3
# 60       2
# 61       2
# 62       2
# 63       1
# 64       1
# 65       8
# 66       2
# 67       2
# 68       2
# 69       3
# 70       3
# 71       3
# 73       4
# 75       6
# 77       2
# 79       2
# ...

# %%
df[df['number_inpatient'] == df['number_inpatient'].max()]
# Out:
#               patient_nbr       race  gender  ... change diabetesMed  readmitted
# encounter_id                                  ...
# 103670874         4790016  Caucasian  Female  ...     No         Yes         <30
#
# [1 rows x 49 columns]

# %%
df.groupby('number_tested').number_confirmed.describe()
# Out:
#                count         mean         std  ...     50%      75%     max
# number_tested                                  ...
# 1               32.0     0.156250    0.368902  ...     0.0     0.00     1.0
# 2               30.0     0.666667    0.479463  ...     1.0     1.00     1.0
# 3                6.0     1.000000    0.894427  ...     1.0     1.75     2.0
# 4                8.0     0.500000    0.534522  ...     0.5     1.00     1.0
# 5                2.0     1.000000    0.000000  ...     1.0     1.00     1.0
# 8                2.0     4.000000    0.000000  ...     4.0     4.00     4.0
# 9                4.0     2.000000    0.000000  ...     2.0     2.00     2.0
# 10               2.0     0.000000    0.000000  ...     0.0     0.00     0.0
# 14               2.0     4.000000    0.000000  ...     4.0     4.00     4.0
# 15               2.0     1.000000    0.000000  ...     1.0     1.00     1.0
# 24               1.0     6.000000         NaN  ...     6.0     6.00     6.0
# ...

# %% [markdown]
# # Visualization

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f31c99e2950>,
# ...
#       dtype=object)

# %%
df.plot()

# %%
df.plot(kind="hist", x="specimen_date" , y="number_confirmed")

# %%
df.count().plot(kind='bar')

# %%
corr = df.corr()
corr
# Out:
#                      number_tested  ...  number_deaths
# number_tested             1.000000  ...      -0.054062
# number_confirmed          0.475581  ...       0.773812
# number_hospitalized       0.032997  ...       0.989150
# number_deaths            -0.054062  ...       1.000000
#
# [4 rows x 4 columns]

# %%
sns.heatmap(corr)

# %%
fig, ax = plt.subplots(figsize=(7,5))
sns.heatmap(corr, square=True)

# %%
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(7, 5))
    ax = sns.heatmap(corr, mask=mask, vmax=1, square=True)

# %%
g = sns.PairGrid(df)
g.map(plt.scatter);

# %% [markdown]
# # Conclusion:
# # As of August 2021 based on the above graphical representation there were only few number of hospitalized and deaths.There were more number of tested people but only few confirmed infected by coronavirus (COVID-19).
