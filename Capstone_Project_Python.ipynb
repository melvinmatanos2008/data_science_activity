# %% [markdown]
# <a href="https://colab.research.google.com/github/melvionmatanos2008/mfmpython1/blob/main/Capstone_Project_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NYPD Arrest Data (Year to Date)
# # Importing required libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import numpy as np

# %%
df = pd.read_csv ('https://data.cityofnewyork.us/resource/uip8-fykc.csv', index_col=0)
print(df)
# Out:
#                         arrest_date  ...                                geocoded_column
# arrest_key                           ...
# 230210509   2021-06-29T00:00:00.000  ...  POINT (-73.73476084899994 40.726293088000034)
# 226147627   2021-03-26T00:00:00.000  ...  POINT (-73.99749074599998 40.716195914000025)
# 226113029   2021-03-25T00:00:00.000  ...  POINT (-73.98722940999993 40.689452980000056)
# 225789182   2021-03-18T00:00:00.000  ...  POINT (-73.90038861799998 40.844139945000045)
# 229613603   2021-06-16T00:00:00.000  ...   POINT (-73.91749507299994 40.69833089400004)
# ...                             ...  ...                                            ...
# 229961262   2021-06-23T00:00:00.000  ...   POINT (-73.87593153399997 40.75656758500002)
# 228745163   2021-05-27T00:00:00.000  ...   POINT (-73.98713326299998 40.73924294500005)
# 229517256   2021-06-14T00:00:00.000  ...        POINT (-73.944006002 40.70196993700006)
# ...

# %%
df
# Out:
#                         arrest_date  ...                                geocoded_column
# arrest_key                           ...
# 230210509   2021-06-29T00:00:00.000  ...  POINT (-73.73476084899994 40.726293088000034)
# 226147627   2021-03-26T00:00:00.000  ...  POINT (-73.99749074599998 40.716195914000025)
# 226113029   2021-03-25T00:00:00.000  ...  POINT (-73.98722940999993 40.689452980000056)
# 225789182   2021-03-18T00:00:00.000  ...  POINT (-73.90038861799998 40.844139945000045)
# 229613603   2021-06-16T00:00:00.000  ...   POINT (-73.91749507299994 40.69833089400004)
# ...                             ...  ...                                            ...
# 229961262   2021-06-23T00:00:00.000  ...   POINT (-73.87593153399997 40.75656758500002)
# 228745163   2021-05-27T00:00:00.000  ...   POINT (-73.98713326299998 40.73924294500005)
# 229517256   2021-06-14T00:00:00.000  ...        POINT (-73.944006002 40.70196993700006)
# ...

# %%
df.head()
# Out:
#                         arrest_date  ...                                geocoded_column
# arrest_key                           ...
# 230210509   2021-06-29T00:00:00.000  ...  POINT (-73.73476084899994 40.726293088000034)
# 226147627   2021-03-26T00:00:00.000  ...  POINT (-73.99749074599998 40.716195914000025)
# 226113029   2021-03-25T00:00:00.000  ...  POINT (-73.98722940999993 40.689452980000056)
# 225789182   2021-03-18T00:00:00.000  ...  POINT (-73.90038861799998 40.844139945000045)
# 229613603   2021-06-16T00:00:00.000  ...   POINT (-73.91749507299994 40.69833089400004)
#
# [5 rows x 18 columns]

# %%
df.tail()
# Out:
#                         arrest_date  ...                                geocoded_column
# arrest_key                           ...
# 229961262   2021-06-23T00:00:00.000  ...   POINT (-73.87593153399997 40.75656758500002)
# 228745163   2021-05-27T00:00:00.000  ...   POINT (-73.98713326299998 40.73924294500005)
# 229517256   2021-06-14T00:00:00.000  ...        POINT (-73.944006002 40.70196993700006)
# 228191109   2021-05-14T00:00:00.000  ...  POINT (-73.79529351199994 40.705312090000064)
# 229780449   2021-06-19T00:00:00.000  ...  POINT (-73.75512455499995 40.705464206000045)
#
# [5 rows x 18 columns]

# %%
df.describe()
# Out:
#              pd_cd        ky_cd  ...     latitude    longitude
# count  1000.000000  1000.000000  ...  1000.000000  1000.000000
# mean    416.723000   241.484000  ...    40.733875   -73.925585
# std     283.443664   151.820292  ...     0.080061     0.079312
# min      49.000000   101.000000  ...    40.511586   -74.249304
# 25%     109.000000   113.000000  ...    40.673549   -73.978441
# 50%     339.000000   233.000000  ...    40.726288   -73.929655
# 75%     705.000000   344.000000  ...    40.807440   -73.881512
# max     969.000000   995.000000  ...    40.896760   -73.712923
#
# [8 rows x 8 columns]

# %% [markdown]
# # Data wrangling and cleaning.
# #Finding the missing values.

# %%
df.isnull().sum()
# Out:
# arrest_date          0
# pd_cd                0
# pd_desc              0
# ky_cd                0
# ofns_desc            0
# law_code             0
# law_cat_cd           9
# arrest_boro          0
# arrest_precinct      0
# jurisdiction_code    0
# age_group            0
# perp_sex             0
# perp_race            0
# x_coord_cd           0
# y_coord_cd           0
# latitude             0
# longitude            0
# geocoded_column      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 230210509 to 229780449
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   arrest_date        1000 non-null   object
#  1   pd_cd              1000 non-null   int64
#  2   pd_desc            1000 non-null   object
#  3   ky_cd              1000 non-null   float64
#  4   ofns_desc          1000 non-null   object
#  5   law_code           1000 non-null   object
#  6   law_cat_cd         991 non-null    object
#  7   arrest_boro        1000 non-null   object
#  8   arrest_precinct    1000 non-null   int64
#  9   jurisdiction_code  1000 non-null   int64
#  10  age_group          1000 non-null   object
#  11  perp_sex           1000 non-null   object
#  12  perp_race          1000 non-null   object
#  13  x_coord_cd         1000 non-null   int64
#  14  y_coord_cd         1000 non-null   int64
# ...

# %% [markdown]
# # Data types summary for each columns.

# %%
df.dtypes
# Out:
# arrest_date           object
# pd_cd                  int64
# pd_desc               object
# ky_cd                float64
# ofns_desc             object
# law_code              object
# law_cat_cd            object
# arrest_boro           object
# arrest_precinct        int64
# jurisdiction_code      int64
# age_group             object
# perp_sex              object
# perp_race             object
# x_coord_cd             int64
# y_coord_cd             int64
# latitude             float64
# longitude            float64
# geocoded_column       object
# dtype: object

# %% [markdown]
# # Showing example of a specific data types.

# %%
df.select_dtypes(include=['number'])
# Out:
#             pd_cd  ky_cd  arrest_precinct  ...  y_coord_cd   latitude  longitude
# arrest_key                                 ...
# 230210509     105  106.0              105  ...      203993  40.726293 -73.734761
# 226147627     177  116.0                5  ...      200203  40.716196 -73.997491
# 226113029     101  344.0               84  ...      190460  40.689453 -73.987229
# 225789182     101  344.0               48  ...      246833  40.844140 -73.900389
# 229613603     397  105.0               83  ...      193705  40.698331 -73.917495
# ...           ...    ...              ...  ...         ...        ...        ...
# 229961262     782  236.0              115  ...      214936  40.756568 -73.875932
# 228745163     101  344.0               13  ...      208600  40.739243 -73.987133
# 229517256     268  121.0               90  ...      195025  40.701970 -73.944006
# 228191109     101  344.0              103  ...      196304  40.705312 -73.795294
# ...

# %%
df.index
# Out:
# Int64Index([230210509, 226147627, 226113029, 225789182, 229613603, 225751057,
#             229518843, 229520735, 225591004, 229372275,
#             ...
#             229214786, 229318235, 229861271, 229091670, 228881582, 229961262,
#             228745163, 229517256, 228191109, 229780449],
#            dtype='int64', name='arrest_key', length=1000)

# %%
df.max()
# Out:
# arrest_date                               2021-06-30T00:00:00.000
# pd_cd                                                         969
# pd_desc                                  WEAPONS, POSSESSION, ETC
# ky_cd                                                         995
# ofns_desc                                VEHICLE AND TRAFFIC LAWS
# law_code                                               VTL1212000
# arrest_boro                                                     S
# arrest_precinct                                               123
# jurisdiction_code                                              97
# age_group                                                     <18
# perp_sex                                                        M
# perp_race                                          WHITE HISPANIC
# x_coord_cd                                                1063798
# y_coord_cd                                                 266020
# ...

# %%
df.min()
# Out:
# arrest_date                               2021-01-09T00:00:00.000
# pd_cd                                                          49
# pd_desc                                   AGGRAVATED HARASSMENT 1
# ky_cd                                                         101
# ofns_desc                                     ADMINISTRATIVE CODE
# law_code                                               ABC0064B00
# arrest_boro                                                     B
# arrest_precinct                                                 1
# jurisdiction_code                                               0
# age_group                                                   18-24
# perp_sex                                                        F
# perp_race                          AMERICAN INDIAN/ALASKAN NATIVE
# x_coord_cd                                                 914928
# y_coord_cd                                                 125757
# ...

# %%
df.mean()
# Out:
# pd_cd                4.167230e+02
# ky_cd                2.414840e+02
# arrest_precinct      6.400200e+01
# jurisdiction_code    1.093000e+00
# x_coord_cd           1.004867e+06
# y_coord_cd           2.066629e+05
# latitude             4.073387e+01
# longitude           -7.392558e+01
# dtype: float64

# %%
df.groupby(['age_group']) ['perp_sex'].count()
# Out:
# age_group
# 18-24    196
# 25-44    571
# 45-64    203
# 65+       11
# <18       19
# Name: perp_sex, dtype: int64

# %%
df.groupby(['ofns_desc']) ['perp_sex'].count()
# Out:
# ofns_desc
# ADMINISTRATIVE CODE                       1
# AGRICULTURE & MRKTS LAW-UNCLASSIFIED      1
# ALCOHOLIC BEVERAGE CONTROL LAW            3
# ANTICIPATORY OFFENSES                     1
# ASSAULT 3 & RELATED OFFENSES            161
# BURGLAR'S TOOLS                           1
# BURGLARY                                 16
# CRIMINAL MISCHIEF & RELATED OF           71
# CRIMINAL TRESPASS                         7
# DANGEROUS DRUGS                          69
# DANGEROUS WEAPONS                        55
# ESCAPE 3                                  1
# FELONY ASSAULT                          118
# FOR OTHER AUTHORITIES                     9
# FORGERY                                  19
# FRAUDS                                    1
# GAMBLING                                  1
# GRAND LARCENY                            35
# GRAND LARCENY OF MOTOR VEHICLE            6
# INTOXICATED & IMPAIRED DRIVING           15
# INTOXICATED/IMPAIRED DRIVING              2
# ...

# %% [markdown]
# # As an initial result male gender got most high offenses as per the NYPD record.

# %%
sns.histplot(df,x='perp_sex')

# %%
df.groupby('ofns_desc').perp_race.describe()
# Out:
#                                      count  ... freq
# ofns_desc                                   ...
# ADMINISTRATIVE CODE                      1  ...    1
# AGRICULTURE & MRKTS LAW-UNCLASSIFIED     1  ...    1
# ALCOHOLIC BEVERAGE CONTROL LAW           3  ...    2
# ANTICIPATORY OFFENSES                    1  ...    1
# ASSAULT 3 & RELATED OFFENSES           161  ...   85
# BURGLAR'S TOOLS                          1  ...    1
# BURGLARY                                16  ...    6
# CRIMINAL MISCHIEF & RELATED OF          71  ...   29
# CRIMINAL TRESPASS                        7  ...    5
# DANGEROUS DRUGS                         69  ...   33
# DANGEROUS WEAPONS                       55  ...   37
# ESCAPE 3                                 1  ...    1
# FELONY ASSAULT                         118  ...   63
# FOR OTHER AUTHORITIES                    9  ...    3
# FORGERY                                 19  ...   12
# FRAUDS                                   1  ...    1
# ...

# %% [markdown]
# # The graph shows assault 3 and other offenses has the highest violations.

# %%
sns.histplot(df,x='ofns_desc')

# %%
df.groupby('ofns_desc').perp_race.describe()
# Out:
#                                      count  ... freq
# ofns_desc                                   ...
# ADMINISTRATIVE CODE                      1  ...    1
# AGRICULTURE & MRKTS LAW-UNCLASSIFIED     1  ...    1
# ALCOHOLIC BEVERAGE CONTROL LAW           3  ...    2
# ANTICIPATORY OFFENSES                    1  ...    1
# ASSAULT 3 & RELATED OFFENSES           161  ...   85
# BURGLAR'S TOOLS                          1  ...    1
# BURGLARY                                16  ...    6
# CRIMINAL MISCHIEF & RELATED OF          71  ...   29
# CRIMINAL TRESPASS                        7  ...    5
# DANGEROUS DRUGS                         69  ...   33
# DANGEROUS WEAPONS                       55  ...   37
# ESCAPE 3                                 1  ...    1
# FELONY ASSAULT                         118  ...   63
# FOR OTHER AUTHORITIES                    9  ...    3
# FORGERY                                 19  ...   12
# FRAUDS                                   1  ...    1
# ...

# %% [markdown]
# # Most of the black people are being arrested.

# %%
sns.histplot(df,x='perp_race')

# %%
df=pd.DataFrame(np.random.rand(50,2),columns=['ofns_desc','perp_race'])
df.plot.scatter(x='perp_race',y='ofns_desc');

# %%
df.groupby('ofns_desc').perp_race.describe()
# Out:
#                                      count  ... freq
# ofns_desc                                   ...
# ADMINISTRATIVE CODE                      1  ...    1
# AGRICULTURE & MRKTS LAW-UNCLASSIFIED     1  ...    1
# ALCOHOLIC BEVERAGE CONTROL LAW           3  ...    2
# ANTICIPATORY OFFENSES                    1  ...    1
# ASSAULT 3 & RELATED OFFENSES           161  ...   85
# BURGLAR'S TOOLS                          1  ...    1
# BURGLARY                                16  ...    6
# CRIMINAL MISCHIEF & RELATED OF          71  ...   29
# CRIMINAL TRESPASS                        7  ...    5
# DANGEROUS DRUGS                         69  ...   33
# DANGEROUS WEAPONS                       55  ...   37
# ESCAPE 3                                 1  ...    1
# FELONY ASSAULT                         118  ...   63
# FOR OTHER AUTHORITIES                    9  ...    3
# FORGERY                                 19  ...   12
# FRAUDS                                   1  ...    1
# ...

# %%
df.groupby('ofns_desc').perp_race.describe()
# Out:
# Empty DataFrame
# Columns: [arrest_date, pd_cd, pd_desc, ky_cd, ofns_desc, law_code, law_cat_cd, arrest_boro, arrest_precinct, jurisdiction_code, age_group, perp_sex, perp_race, x_coord_cd, y_coord_cd, latitude, longitude, geocoded_column]
# Index: []

# %%
df.groupby('ofns_desc').perp_race.describe()
# Out:
#                                      count  ... freq
# ofns_desc                                   ...
# ADMINISTRATIVE CODE                      1  ...    1
# AGRICULTURE & MRKTS LAW-UNCLASSIFIED     1  ...    1
# ALCOHOLIC BEVERAGE CONTROL LAW           3  ...    2
# ANTICIPATORY OFFENSES                    1  ...    1
# ASSAULT 3 & RELATED OFFENSES           161  ...   85
# BURGLAR'S TOOLS                          1  ...    1
# BURGLARY                                16  ...    6
# CRIMINAL MISCHIEF & RELATED OF          71  ...   29
# CRIMINAL TRESPASS                        7  ...    5
# DANGEROUS DRUGS                         69  ...   33
# DANGEROUS WEAPONS                       55  ...   37
# ESCAPE 3                                 1  ...    1
# FELONY ASSAULT                         118  ...   63
# FOR OTHER AUTHORITIES                    9  ...    3
# FORGERY                                 19  ...   12
# FRAUDS                                   1  ...    1
# ...

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbaa5621110>,
# ...
#       dtype=object)

# %%
df.plot()

# %%
df.count().plot(kind='bar')

# %%
corr = df.corr()
corr
# Out:
#                       pd_cd     ky_cd  ...  latitude  longitude
# pd_cd              1.000000  0.066911  ... -0.099130  -0.051847
# ky_cd              0.066911  1.000000  ...  0.006137   0.001949
# arrest_precinct    0.083546 -0.009764  ... -0.466911   0.267948
# jurisdiction_code  0.095880  0.048539  ...  0.006641  -0.050873
# x_coord_cd        -0.051796  0.001879  ...  0.268731   0.999999
# y_coord_cd        -0.099122  0.006162  ...  1.000000   0.270489
# latitude          -0.099130  0.006137  ...  1.000000   0.269870
# longitude         -0.051847  0.001949  ...  0.269870   1.000000
#
# [8 rows x 8 columns]

# %%
sns.heatmap(corr)

# %%
fig, ax = plt.subplots(figsize=(7,5))
sns.heatmap(corr, square=True)

# %%
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(7, 5))
    ax = sns.heatmap(corr, mask=mask, vmax=1, square=True)

# %%
g = sns.PairGrid(df)
g.map(plt.scatter);

# %% [markdown]
# # Conclusion:
# # Mostly black people has been arrested with the highest assult 3 and other offenses. It was also concluded that male has the committed more offenses than female.
